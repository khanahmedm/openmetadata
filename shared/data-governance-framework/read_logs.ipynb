# %%
import pandas as pd

# Load the log file
log_path = "local_logs/pipeline_run_20250707_045059.log"  # use your actual path
df = pd.read_json(log_path, lines=True)

# Preview the data
df.head()
# Out:
#                       time   pipeline     schema   table level         module  \
# 0  2025-07-07 04:50:59,138  pangenome  pangenome  genome  INFO     3421723309
# 1  2025-07-07 04:50:59,149  pangenome  pangenome  genome  INFO  config_loader
# 2  2025-07-07 04:50:59,150  pangenome  pangenome  genome  INFO  config_loader
# 3  2025-07-07 04:50:59,151  pangenome  pangenome  genome  INFO  config_loader
# 4  2025-07-07 04:50:59,335  pangenome  pangenome  genome  INFO  config_loader
#
#                                                  msg
# 0                                   Notebook started
# 1  ConfigLoader initialized for target table: genome
# 2  Resolved config path: s3a://cdm-lake/config-js...
# 3  Loading config from MinIO: bucket=cdm-lake, ke...
# 4              Config loaded successfully from MinIO
